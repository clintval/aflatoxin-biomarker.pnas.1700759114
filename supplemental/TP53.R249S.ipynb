# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

hg38_path = '/home/clint/buffalo/hg38/hg38.fa'
cosmic_mutants = '/home/clint/buffalo/cosmic/v76/CosmicMutantExport_LiverHCC.tsv'

# %%
from siglib.cosmic import merge_samples, parse_to_samples

merged_samples = merge_samples(parse_to_samples(cosmic_mutants))
merged_filtered_samples = [x for x in merged_samples.values() if len(x.mutations) in range(100, 8000)]

# %% [markdown]
# Discovery of Target Residues
# ---

# %%
with_target_residue = 0

for sample in merged_filtered_samples:
    for m in sample.mutations:
        if m.AA == 'p.R249S' and m.chrom == 'chr17' and m.position[0] == 7674216:
            with_target_residue += 1
            print(sample, "\n")
            break
# Out:
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-CC-A3MB-01
# Site: liver
# Mutations: 313 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000317216
# HGNC ID:                                         3240
# Pubmed ID:
# Sample ID:                                    2194595
# Study ID:                                         628
# Tumour ID:                                    2062873
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               36
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: CHC1704T
# Site: liver
# Mutations: 589 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000441788
# HGNC ID:                                        24824
# Pubmed ID:                                   25822088
# Sample ID:                                    2340950
# Study ID:                                         381
# Tumour ID:                                    2205933
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               43
# Genome Wide Screen:                                 y
# Sample Source:                   surgery fresh/frozen
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-CC-A7II-01
# Site: liver
# Mutations: 249 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000327697
# HGNC ID:                                        21148
# Pubmed ID:
# Sample ID:                                    2339864
# Study ID:                                         628
# Tumour ID:                                    2204847
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               54
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-G3-A25U-01
# Site: liver
# Mutations: 334 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000454349
# HGNC ID:                                        29190
# Pubmed ID:
# Sample ID:                                    2194556
# Study ID:                                         628
# Tumour ID:                                    2062834
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               63
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-CC-A5UE-01
# Site: liver
# Mutations: 222 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000425854
# HGNC ID:
# Pubmed ID:
# Sample ID:                                    2340542
# Study ID:                                         628
# Tumour ID:                                    2205525
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               48
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: 3206A7_009_T
# Site: liver
# Mutations: 477 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000367567
# HGNC ID:
# Pubmed ID:                                   25159915
# Sample ID:                                    2390298
# Study ID:
# Tumour ID:                                    2253130
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: CHC1154T
# Site: liver
# Mutations: 281 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000359596
# HGNC ID:                                        10483
# Pubmed ID:                                   25822088
# Sample ID:                                    2194458
# Study ID:                                         381
# Tumour ID:                                    2062736
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               44
# Genome Wide Screen:                                 y
# Sample Source:                   surgery fresh/frozen
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: 3206A7_017_T
# Site: liver
# Mutations: 310 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000323146
# HGNC ID:                                        20753
# Pubmed ID:                                   25159915
# Sample ID:                                    2390299
# Study ID:
# Tumour ID:                                    2253131
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: 169T
# Site: liver
# Mutations: 108 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000324856
# HGNC ID:                                        11110
# Pubmed ID:                                   23788652
# Sample ID:                                    2067156
# Study ID:
# Tumour ID:                                    1946953
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:
# Genome Wide Screen:                                 y
# Sample Source:                          surgery - NOS
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-QA-A7B7-01
# Site: liver
# Mutations: 155 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000397697
# HGNC ID:
# Pubmed ID:
# Sample ID:                                    2340191
# Study ID:                                         628
# Tumour ID:                                    2205174
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               48
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-CC-A3M9-01
# Site: liver
# Mutations: 235 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000425528
# HGNC ID:
# Pubmed ID:
# Sample ID:                                    2194601
# Study ID:                                         628
# Tumour ID:                                    2062879
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               45
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: CHC1035T
# Site: liver
# Mutations: 224 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000020673
# HGNC ID:
# Pubmed ID:                                   25822088
# Sample ID:                                    2428773
# Study ID:                                         381
# Tumour ID:                                    2291685
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               68
# Genome Wide Screen:                                 y
# Sample Source:                   surgery fresh/frozen
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-ED-A7XP-01
# Site: liver
# Mutations: 105 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000335568
# HGNC ID:                                        13479
# Pubmed ID:
# Sample ID:                                    2194541
# Study ID:                                         628
# Tumour ID:                                    2062819
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               53
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: CHC1754T
# Site: liver
# Mutations: 355 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000400664
# HGNC ID:                                        26791
# Pubmed ID:                                   25822088
# Sample ID:                                    2340455
# Study ID:                                         381
# Tumour ID:                                    2205438
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               34
# Genome Wide Screen:                                 y
# Sample Source:                   surgery fresh/frozen
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: 203T
# Site: liver
# Mutations: 111 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000308008
# HGNC ID:
# Pubmed ID:                                   23788652
# Sample ID:                                    2067168
# Study ID:
# Tumour ID:                                    1946965
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:
# Genome Wide Screen:                                 y
# Sample Source:                          surgery - NOS
# Tumour Origin:                                primary
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
#
# OVERVIEW
# -----------------------------------------------------
# Sample: TCGA-DD-A114-01
# Site: liver
# Mutations: 175 mutations
# Histology: hepatocellular_carcinoma carcinoma
#
# IDENTIFIERS
# -----------------------------------------------------
# Accession:                            ENST00000254488
# HGNC ID:                                        11044
# Pubmed ID:
# Sample ID:                                    2194598
# Study ID:                                         628
# Tumour ID:                                    2062876
#
# CLINICAL INFORMATION
# -----------------------------------------------------
# Age:                                               42
# Genome Wide Screen:                                 y
# Sample Source:                                     NS
# Tumour Origin:                                     NS
#
# SITE
# -----------------------------------------------------
# Primary:                                        liver
# Subtype 1:                                         NS
# Subtype 2:                                         NS
# Subtype 3:                                         NS
#
# HISTOLOGY
# -----------------------------------------------------
# Primary:                                    carcinoma
# Subtype 1:                   hepatocellular_carcinoma
# Subtype 2:                                         NS
# Subtype 3:                                         NS

# %%
print("Samples with p.R249S:  {}".format(with_target_residue))
print("Total Population:      {}".format(len(merged_filtered_samples)))
p = with_target_residue / len(merged_filtered_samples)
print('Population Proportion: {:.3%}'.format(p))
# Out:
# Samples with p.R249S:  16
# Total Population:      314
# Population Proportion: 5.096%

# %% [markdown]
# Statistical Test
# ---
#
# $\mathrm{H}_{\mathrm{o}}$: The null hypothesis is that the probability of observed R249S mutated samples in a selected cohort is equal to the probability of R249S mutated samples in the population.
#
# $\mathrm{H}_{\mathrm{A}}$: The alternate hypothesis is that the probability of R249S mutated samples is different in the cohort than in the true population.
#
# This is a two-sided exact test of a Bernouilli experiment. If a one-sided test is needed then we will need to use the `binom.test` routine in the `R` language. If we want to search for other potentially correlated metdata we will need to multiple hypothesis correct.

# %%
from scipy.stats import binom_test

print('p-value: {:0.3}'.format(binom_test(x=7, n=13, p=p)))
# Out:
# p-value: 1.16e-06

# %% [markdown]
# Considering all Mutated Residues $(n > 3)$
# ---
#
# 1. Count the occurence of each mutated residue in the dataset.
# 2. Select residues that appear more than 3 times.
# 3. Test enrichment of residue in selected cohort.

# %%
from collections import Counter

residues = Counter()

for sample in merged_filtered_samples:
    for mutation in sample.mutations:
        residues[(mutation.chrom, mutation.position[0], mutation.AA)] += 1
print("There are {:,} unique mutated residues".format(len(residues)))
# Out:
# There are 55,455 unique mutated residues

# %%
selected_residues = []

for residue, count in sorted(residues.items()):
    if count > 3:
        selected_residues.append(residue)
print("There are {:,} selected residues".format(len(selected_residues)))
# Out:
# There are 285 selected residues

# %%
group = ['067T',
         'TCGA-CC-A7IL-01', 'TCGA-CC-A7II-01', 'TCGA-CC-A7IG-01', 'TCGA-DD-A1EL-01', 'TCGA-DD-A114-01',
         'CHC1704T', 'CHC1211T', 'CHC1754T', 'CHC1154T', 'CHC1717T',
         '3206A7_009_T', '3206A7_017_T']

# %%
p_values = []

for residue in selected_residues:
    in_group = with_target_residue = 0
    for sample in merged_filtered_samples:
        for m in sample.mutations:
            if residue == (m.chrom, m.position[0], m.AA):
                if sample.name in group:
                    in_group += 1
                with_target_residue += 1
                break
    p_values.append(binom_test(in_group, len(group), with_target_residue / len(merged_filtered_samples)))

# %% [markdown]
# Correct p-values for Multiple Hypothesis Testing
# ---
# Use Benjamnini/Hochberg (non-negative) formula

# %%
from statsmodels.sandbox.stats.multicomp import multipletests

alpha = 0.05
reject, pvals_corrected, *_ = multipletests(p_values, alpha, 'fdr_bh')
print("The number of residues below α={} with a different proportion in our samples: {}".format(alpha, sum(reject)))
# Out:
# The number of residues below α=0.05 with a different proportion in our samples: 1

# %% [markdown]
# What Residues are Significantly Different?
# ---

# %%
import numpy as np

for residue, pval in zip(np.array(selected_residues)[reject], pvals_corrected[reject]):
    print("Residue {} in {}:{:,} (FDR p-value: {:0.2e})".format(residue[2], residue[0], int(residue[1]), pval))
# Out:
# Residue p.R249S in chr17:7,674,216 (FDR p-value: 3.32e-04)
